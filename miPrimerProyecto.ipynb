# %% [markdown]
# <a href="https://colab.research.google.com/github/RamaelCordova/PrograIII-Semi-2026/blob/main/miPrimerProyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saludo = "Hola chicos de progra III"
print(saludo, "Priemra letra del saludo", saludo[0:4])

num1 = 5.25
print(num1)

booleano = True
print(booleano)
# Out:
# Hola chicos de progra III Priemra letra del saludo Hola
# 5.25
# True

# %%
print("sumar dos nuemros")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) + float(num2)

print(type(num1), type(num2), type(respuesta))

print("respuesta: ", respuesta)

respuesta = "Suma completa"
print(respuesta, type(respuesta))
# Out:
# sumar dos nuemros
# Num 1: 5.5
# Num 2: 6
# <class 'str'> <class 'str'> <class 'float'>
# respuesta:  11.5
# Suma completa <class 'str'>

# %%
print("restar dos nuemros")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) - float(num2)

print(type(num1), type(num2), type(respuesta))

print("respuesta: ", respuesta)

respuesta = "resta completa"
print(respuesta, type(respuesta))
# Out:
# restar dos nuemros
# Num 1: 5.5
# Num 2: 6
# <class 'str'> <class 'str'> <class 'float'>
# respuesta:  -0.5
# resta completa <class 'str'>

# %%
print("multiplicar dos nuemros")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) * float(num2)

print(type(num1), type(num2), type(respuesta))

print("respuesta: ", respuesta)

respuesta = "MUltiplicacion completa"
print(respuesta, type(respuesta))
# Out:
# multiplicar dos nuemros
# Num 1: 5.5
# Num 2: 6
# <class 'str'> <class 'str'> <class 'float'>
# respuesta:  33.0
# MUltiplicacion completa <class 'str'>

# %%
print("dividir dos nuemros")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) / float(num2)

print(type(num1), type(num2), type(respuesta))

print("respuesta: ", respuesta)

respuesta = "Division completa"
print(respuesta, type(respuesta))
# Out:
# dividir dos nuemros
# Num 1: 5.5
# Num 2: 6
# <class 'str'> <class 'str'> <class 'float'>
# respuesta:  0.9166666666666666
# Division completa <class 'str'>
